# %% [markdown]
# <a href="https://colab.research.google.com/github/Sean09-git/immune-cli/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, AI World!")
# Out:
# Hello, AI World!

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

print("Data Mining Tools are Ready!")
# Out:
# Data Mining Tools are Ready!
